# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetabhosale15/shweta/blob/main/Deep_Learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DEEP LEARNING PROJECT

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
# %matplotlib inline

# %%
df_Dealers=pd.read_excel('/content/Dataset.xlsx',sheet_name='Dealers')

# %%
df_Dealers
# Out:
#       Dealer_ID       Dealer_Name Dealer_Country        State       City  \
# 0           1.0   Kenneth Schmitt          india          Goa      Panji
# 1           2.0   Owen Mclaughlin          india        Delhi     Naoida
# 2           3.0   Donald Repinski          india    Karnataka  Bangalore
# 3           4.0     Rachel Oszust          india       Gujrat  Ahemdabad
# 4           5.0        Lynn Knapp          india       Orrisa    Cuttack
# ...         ...               ...            ...          ...        ...
# 1995     1996.0  Darleen Sullivan          india    Karnataka  Bangalore
# 1996     1997.0    Bobbie Dretzka          india       Gujrat  Ahemdabad
# 1997     1998.0     Colin Wiggins          india       Orrisa    Cuttack
# 1998     1999.0      Marie Groves          india  Maharashtra     Mumbai
# 1999     2000.0  Richard Schwartz          india          Goa      Panji
#
#        ZIpCode
# 0     400001.0
# 1     400002.0
# 2     400003.0
# 3     400004.0
# ...

# %%
df_customers=pd.read_excel('/content/Dataset.xlsx',sheet_name='Customers')

# %%
df_customers
# Out:
#          Cust_ID Cust_Name  Dealer_ID Country        State        City  \
# 0          101.0   pushpak        1.0     ind          goa      panaji
# 1          102.0       raj        3.0     ind    karnataka    banglore
# 2          103.0    ranbir        4.0     ind       gujrat  ahemadabad
# 3          104.0   reyansh        5.0     ind       orrisa     cuttack
# 4          105.0    raunak        2.0     ind        delhi       noida
# ...          ...       ...        ...     ...          ...         ...
# 287995  287996.0   Michael        5.0     ind        delhi       noida
# 287996  287997.0       Tim        4.0     ind  maharashtra      mumbai
# 287997  287998.0    Laurie        5.0     ind       orrisa     cuttack
# 287998  287999.0     Katie        2.0     ind    karnataka    banglore
# 287999  288000.0     Karly        6.0     ind          goa      panaji
#
#          ZipCode
# 0       402201.0
# 1       403315.0
# 2       326665.0
# 3       543211.0
# 4       426232.0
# ...

# %%
df_claims=pd.read_excel('/content/Dataset.xlsx',sheet_name='Claims')

# %%
df_claims
# Out:
#        claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0           1.0 2020-04-01       36000.0        5.0    104.0    901.0
# 1           2.0 2020-04-01       42000.0        6.0    106.0    902.0
# 2           3.0 2020-04-01       45000.0        4.0    103.0    903.0
# 3           4.0 2020-04-01       56000.0        3.0    102.0    904.0
# 4           5.0 2020-04-01       39000.0        2.0    105.0    905.0
# ...         ...        ...           ...        ...      ...      ...
# 20090   20091.0 2021-01-24       53000.0     1274.0  43974.0    906.0
# 20091   20092.0 2021-01-24       36000.0     1275.0  43975.0    907.0
# 20092   20093.0 2021-01-24       46000.0     1276.0  43976.0    905.0
# 20093   20094.0 2021-01-24       56000.0     1277.0  43977.0    904.0
# 20094   20095.0 2021-01-24       33000.0     1278.0  43978.0    902.0
#
#       Repair_or_Replace
# 0                   rpr
# 1                  rplc
# 2                   rpr
# 3                  rplc
# ...

# %%
df_parts=pd.read_excel('/content/Dataset.xlsx',sheet_name='Parts')

# %%
df_parts
# Out:
#     Part_ID          Part_Name  Manufacturer_ID  Manf_Date
# 0     901.0          brake pad            501.0 1996-08-12
# 1     902.0              axle             502.0 1997-03-03
# 2     903.0            tie rod            503.0 1997-06-13
# 3     904.0       differential            504.0 1997-01-14
# 4     905.0    rear suspension            505.0 1996-08-19
# 5     906.0           radiator            506.0 1997-03-24
# 6     907.0        clutch kits            503.0 1997-05-12
# 7     908.0    pressure plates            502.0 1997-05-20
# 8     909.0          flywheels            505.0 1997-06-29
# 9     910.0  torque converters            506.0 1997-07-17
# 10    911.0         flexplates            501.0 1997-08-23

# %%
df_transaction=pd.read_excel('/content/Dataset.xlsx',sheet_name='Transactions')

# %%
df_transaction
# Out:
#        transaction_id  claim_id transaction_date  transaction_amount
# 0               101.0       1.0       2020-04-01             36000.0
# 1               102.0       2.0       2020-04-01             42000.0
# 2               103.0       3.0       2020-04-01             45000.0
# 3               104.0       4.0       2020-04-01             56000.0
# 4               105.0       5.0       2020-04-01             39000.0
# ...               ...       ...              ...                 ...
# 20090         20091.0   20091.0       2021-01-24             53000.0
# 20091         20092.0   20092.0       2021-01-24             36000.0
# 20092         20093.0   20093.0       2021-01-24             46000.0
# 20093         20094.0   20094.0       2021-01-24             56000.0
# 20094         20095.0   20095.0       2021-01-24             33000.0
#
# [20095 rows x 4 columns]

# %%
df_vendor=pd.read_excel('/content/Dataset.xlsx',sheet_name='Vendors')

# %%
df_vendor
# Out:
#    Vendor_ID     Name Country        State        City   ZIpCode
# 0      501.0    Advik     ind          goa      panaji  400001.0
# 1      502.0    Rudra     ind        delhi       noida  400002.0
# 2      503.0  Aayansh     ind    karnataka    banglore  400003.0
# 3      504.0   Adinew     ind       gujrat  ahemadabad  400004.0
# 4      505.0    Dhruv     ind       orrisa     cuttack  400005.0
# 5      506.0     Veer     ind  maharashtra      mumbai  400006.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288000 entries, 0 to 287999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Cust_ID    288000 non-null  float64
#  1   Cust_Name  288000 non-null  object
#  2   Dealer_ID  288000 non-null  float64
#  3   Country    288000 non-null  object
#  4   State      288000 non-null  object
#  5   City       288000 non-null  object
#  6   ZipCode    288000 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ MB

# %%
#use case1:Monthly report of top ten Dealers and parts that has been failed:

# %%
df_claims['Dealer_ID'].value_counts().head(10)
# Out:
# 5.0       971
# 3.0       922
# 2.0       922
# 1.0       922
# 6.0       394
# 4.0       218
# 1248.0    176
# 1256.0    176
# 1255.0    176
# 1254.0    176
# Name: Dealer_ID, dtype: int64

# %%
df_claims['Part_ID'].value_counts().head(10)
# Out:
# 906.0    4019
# 901.0    3349
# 905.0    3349
# 907.0    3348
# 902.0    2010
# 903.0    2010
# 904.0    2010
# Name: Part_ID, dtype: int64

# %%
df_claims['Repair_or_Replace'].value_counts()
# Out:
# rplc    14736
# rpr      5359
# Name: Repair_or_Replace, dtype: int64

# %%
df_claims[['Repair_or_Replace','Part_ID']].value_counts()
# Out:
# Repair_or_Replace  Part_ID
# rplc               906.0      3349
#                    907.0      3348
#                    904.0      2010
#                    905.0      2009
# rpr                901.0      2009
# rplc               901.0      1340
#                    902.0      1340
#                    903.0      1340
# rpr                905.0      1340
#                    902.0       670
#                    903.0       670
#                    906.0       670
# dtype: int64

# %%
repl_or_rep=pd.get_dummies(df_claims['Repair_or_Replace'],drop_first=True)

# %%
repl_or_rep
# Out:
#        rpr
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ...    ...
# 20090    0
# 20091    0
# 20092    0
# 20093    0
# 20094    1
#
# [20095 rows x 1 columns]

# %%
df_claims
# Out:
#        claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0           1.0 2020-04-01       36000.0        5.0    104.0    901.0
# 1           2.0 2020-04-01       42000.0        6.0    106.0    902.0
# 2           3.0 2020-04-01       45000.0        4.0    103.0    903.0
# 3           4.0 2020-04-01       56000.0        3.0    102.0    904.0
# 4           5.0 2020-04-01       39000.0        2.0    105.0    905.0
# ...         ...        ...           ...        ...      ...      ...
# 20090   20091.0 2021-01-24       53000.0     1274.0  43974.0    906.0
# 20091   20092.0 2021-01-24       36000.0     1275.0  43975.0    907.0
# 20092   20093.0 2021-01-24       46000.0     1276.0  43976.0    905.0
# 20093   20094.0 2021-01-24       56000.0     1277.0  43977.0    904.0
# 20094   20095.0 2021-01-24       33000.0     1278.0  43978.0    902.0
#
#       Repair_or_Replace
# 0                   rpr
# 1                  rplc
# 2                   rpr
# 3                  rplc
# ...

# %%
df_claims.drop(['Repair_or_Replace'],axis=1,inplace=True)

# %%
df_claims
# Out:
#        claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID
# 0           1.0 2020-04-01       36000.0        5.0    104.0    901.0
# 1           2.0 2020-04-01       42000.0        6.0    106.0    902.0
# 2           3.0 2020-04-01       45000.0        4.0    103.0    903.0
# 3           4.0 2020-04-01       56000.0        3.0    102.0    904.0
# 4           5.0 2020-04-01       39000.0        2.0    105.0    905.0
# ...         ...        ...           ...        ...      ...      ...
# 20090   20091.0 2021-01-24       53000.0     1274.0  43974.0    906.0
# 20091   20092.0 2021-01-24       36000.0     1275.0  43975.0    907.0
# 20092   20093.0 2021-01-24       46000.0     1276.0  43976.0    905.0
# 20093   20094.0 2021-01-24       56000.0     1277.0  43977.0    904.0
# 20094   20095.0 2021-01-24       33000.0     1278.0  43978.0    902.0
#
# [20095 rows x 6 columns]

# %%
df_claims=pd.concat([df_claims,repl_or_rep],axis=1)

# %%
df_claims
# Out:
#        claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  rpr
# 0           1.0 2020-04-01       36000.0        5.0    104.0    901.0    1
# 1           2.0 2020-04-01       42000.0        6.0    106.0    902.0    0
# 2           3.0 2020-04-01       45000.0        4.0    103.0    903.0    1
# 3           4.0 2020-04-01       56000.0        3.0    102.0    904.0    0
# 4           5.0 2020-04-01       39000.0        2.0    105.0    905.0    1
# ...         ...        ...           ...        ...      ...      ...  ...
# 20090   20091.0 2021-01-24       53000.0     1274.0  43974.0    906.0    0
# 20091   20092.0 2021-01-24       36000.0     1275.0  43975.0    907.0    0
# 20092   20093.0 2021-01-24       46000.0     1276.0  43976.0    905.0    0
# 20093   20094.0 2021-01-24       56000.0     1277.0  43977.0    904.0    0
# 20094   20095.0 2021-01-24       33000.0     1278.0  43978.0    902.0    1
#
# [20095 rows x 7 columns]

# %%
df_claims.columns=['claim_id', 'claim_date', 'claim_amount', 'Dealer_ID', 'Cust_ID',
       'Part_ID','Target_col']

# %%
df_claims.corr()
# Out:
#               claim_id  claim_amount  Dealer_ID   Cust_ID   Part_ID  \
# claim_id      1.000000      0.000214   0.002988 -0.000791  0.000189
# claim_amount  0.000214      1.000000  -0.000154 -0.001481 -0.285543
# Dealer_ID     0.002988     -0.000154   1.000000  0.007710 -0.002561
# Cust_ID      -0.000791     -0.001481   0.007710  1.000000  0.002312
# Part_ID       0.000189     -0.285543  -0.002561  0.002312  1.000000
# Target_col   -0.000169     -0.264751   0.000630 -0.001301 -0.364181
#
#               Target_col
# claim_id       -0.000169
# claim_amount   -0.264751
# Dealer_ID       0.000630
# Cust_ID        -0.001301
# Part_ID        -0.364181
# Target_col      1.000000

# %%
df_claims
# Out:
#        claim_id claim_date  claim_amount  Dealer_ID  Cust_ID  Part_ID  \
# 0           1.0 2020-04-01       36000.0        5.0    104.0    901.0
# 1           2.0 2020-04-01       42000.0        6.0    106.0    902.0
# 2           3.0 2020-04-01       45000.0        4.0    103.0    903.0
# 3           4.0 2020-04-01       56000.0        3.0    102.0    904.0
# 4           5.0 2020-04-01       39000.0        2.0    105.0    905.0
# ...         ...        ...           ...        ...      ...      ...
# 20090   20091.0 2021-01-24       53000.0     1274.0  43974.0    906.0
# 20091   20092.0 2021-01-24       36000.0     1275.0  43975.0    907.0
# 20092   20093.0 2021-01-24       46000.0     1276.0  43976.0    905.0
# 20093   20094.0 2021-01-24       56000.0     1277.0  43977.0    904.0
# 20094   20095.0 2021-01-24       33000.0     1278.0  43978.0    902.0
#
#        Target_col
# 0               1
# 1               0
# 2               1
# 3               0
# 4               1
# ...

# %%
df_claims.drop(['claim_date', 'Dealer_ID', 'Cust_ID'],axis=1,inplace=True)

# %%
df_claims
# Out:
#        claim_id  claim_amount  Part_ID  Target_col
# 0           1.0       36000.0    901.0           1
# 1           2.0       42000.0    902.0           0
# 2           3.0       45000.0    903.0           1
# 3           4.0       56000.0    904.0           0
# 4           5.0       39000.0    905.0           1
# ...         ...           ...      ...         ...
# 20090   20091.0       53000.0    906.0           0
# 20091   20092.0       36000.0    907.0           0
# 20092   20093.0       46000.0    905.0           0
# 20093   20094.0       56000.0    904.0           0
# 20094   20095.0       33000.0    902.0           1
#
# [20095 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x=df_claims[['claim_id','claim_amount','Part_ID']]
y=df_claims['Target_col']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
x_test.shape
# Out:
# (4019, 3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[2950    0]
#  [   0 1069]]

# %%
(2950+1069)/4019*100
# Out:
# 100.0
